# %%
import random
def biggest_number(numlist):
  numlist.sort()
  num_big = numlist[2]
  return num_big

numlist = [random.randint(1,10000), random.randint(1,10000), random.randint(1,10000)]
biggest_number(numlist)
print('The biggest number here is: %d' % biggest_number(numlist))
# Out:
# The biggest number here is: 9638
