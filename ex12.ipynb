# %%
def newlist(a):
  length = len(a)
  new_list = []
  new_list.append(a[0])
  new_list.append(a[len(a)-1])
  return new_list

a = [5, 10, 15, 20, 25]

print(a)
print(newlist(a))
# Out:
# [5, 10, 15, 20, 25]
# [5, 25]
