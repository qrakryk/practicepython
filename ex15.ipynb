# %%
#http://www.practicepython.org/exercise/2014/05/21/15-reverse-word-order.html

def sentence_reverse(sentence):
  sentence_list = sentence.split(' ') #rozdziela zdanie do listy słów, element listy identyfikuje po spacji
  sentence_list.reverse()
  reversed_text = ' ' #tworzy miejsce
  return reversed_text.join(sentence_list) #scala liste, dodając spacje co słowo (wynika to z miejsca z linijki wyżej)

print(sentence_reverse('Should we go to that cinema?'))
# Out:
# cinema? that to go we Should
