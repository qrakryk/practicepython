# %%
#http://www.practicepython.org/exercise/2014/03/19/07-list-comprehensions.html

a = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

b = [number for number in a if number %2 == 0] #pierwsze "number" wskazuje jak będę nazywał zmienną iterującą przez "for", drugie "number" należy do komendy "for", trzecie "number" należy do komendy "if"

print(b)
# Out:
# [4, 16, 36, 64, 100]
